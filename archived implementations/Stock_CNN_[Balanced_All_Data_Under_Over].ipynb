# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/CNN Stock Prediction"
# Out:
# /content/drive/.shortcut-targets-by-id/11M8JhuGjMeTkxBAoI1sL3lLEa69ylHrV/CNN Stock Prediction

# %% [markdown]
# #Setup Data with Best Features

# %%
import pandas as pd
stock = "IBM"
labeled_path = f"data/labeled_indicators/{stock}_model_labeled_indicators.csv"
df = pd.read_csv(labeled_path)

cleaned_df = df.drop(['Unnamed: 0'], axis=1)
cleaned_df = cleaned_df.dropna()
cleaned_df.head(50)

# drop non feature columns
cols_to_drop = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "adjustRatio"]
cleaned_df = cleaned_df.drop(cols_to_drop, axis = 1)

# drop last 5 rows
cleaned_df = cleaned_df.iloc[:-5, :]

cleaned_df.head() #(4971, 421) # 420 features + label column
# Out:
#     Label   RSI_ta_6   RSI_ta_7   RSI_ta_8   RSI_ta_9  RSI_ta_10  RSI_ta_11  \
# 59      0  10.900907  13.984287  16.808864  19.335721  21.561469  23.502503
# 60      1   6.896011   9.373318  11.775636  14.029307  16.097933  17.969272
# 61      0  12.323443  14.017505  15.820532  17.601332  19.288652  20.847486
# 62      0  17.397102  18.306041  19.523081  20.849862  22.176042  23.441957
# 63      0  39.974992  37.884477  36.745996  36.181767  35.963598  35.950929
#
#     RSI_ta_12  RSI_ta_13  RSI_ta_14  ...  AWSM_ta_11  AWSM_ta_12  AWSM_ta_13  \
# 59  25.184977  26.638602  27.893021  ...   -1.007045   -0.709792   -0.436346
# 60  19.645962  21.139139  22.464201  ...   -1.432955   -1.107917   -0.837115
# 61  22.264740  23.540211  24.680870  ...   -1.928409   -1.534792   -1.239038
# 62  24.617978  25.692290  26.663413  ...   -2.335227   -1.991875   -1.582308
# 63  36.056389  36.225617  36.425001  ...   -2.545000   -2.361042   -1.959808
#
#     AWSM_ta_14  AWSM_ta_15  AWSM_ta_16  AWSM_ta_17  AWSM_ta_18  AWSM_ta_19  \
# 59   -0.237143    0.036833    0.298906    0.521176    0.798333    1.004211
# 60   -0.604107   -0.379667   -0.099531    0.143529    0.447083    0.668553
# 61   -0.990536   -0.759667   -0.490469   -0.230147    0.055278    0.327368
# 62   -1.314821   -1.105833   -0.856562   -0.583971   -0.343889    0.013026
# 63   -1.593036   -1.354167   -1.152813   -0.869265   -0.620417   -0.345000
#
#     AWSM_ta_20
# 59    1.098000
# 60    0.848500
# 61    0.557500
# 62    0.230875
# 63   -0.025000
#
# [5 rows x 421 columns]

# %%
# count labels
cleaned_df.Label.value_counts()
# Out:
# Label
# 0    3399
# 2     251
# 1     244
# Name: count, dtype: int64

# %% [markdown]
# ###Retrieve Data with Best Features

# %%
import pandas as pd

stock = "IBM"
data_path = f"data/{stock}_selected_features.csv"
df = pd.read_csv(data_path)

df = df.drop(['Unnamed: 0'], axis=1)

df.head() #(225, 1)
# Out:
#            0
# 0   RSI_ta_6
# 1   RSI_ta_7
# 2   RSI_ta_8
# 3   RSI_ta_9
# 4  RSI_ta_10

# %%
max_accuracy_features = df.T # transpose dataframe

headers = max_accuracy_features.iloc[0]
features = pd.DataFrame(max_accuracy_features.values[1:], columns=headers) # best feature columns (0, 225) shape

features.insert(0, "Label", "")

features.head()
# Out:
# Empty DataFrame
# Columns: [Label, RSI_ta_6, RSI_ta_7, RSI_ta_8, RSI_ta_9, RSI_ta_10, RSI_ta_11, RSI_ta_12, RSI_ta_13, RSI_ta_14, RSI_ta_15, RSI_ta_16, RSI_ta_17, RSI_ta_18, RSI_ta_19, RSI_ta_20, WILLR_ta_6, WILLR_ta_7, WILLR_ta_8, WILLR_ta_9, WILLR_ta_10, WILLR_ta_11, WILLR_ta_12, WILLR_ta_13, WILLR_ta_14, WILLR_ta_15, WILLR_ta_16, WILLR_ta_17, WILLR_ta_18, WILLR_ta_19, WILLR_ta_20, HMA_6, HMA_7, TEMA_talib_6, TEMA_talib_7, TEMA_talib_8, CCI_ta_6, CCI_ta_7, CCI_ta_8, CCI_ta_9, CCI_ta_10, CCI_ta_11, CCI_ta_12, CCI_ta_13, CCI_ta_14, CCI_ta_15, CCI_ta_16, CCI_ta_17, CCI_ta_18, CCI_ta_19, CCI_ta_20, CMO_talib_6, CMO_talib_7, CMO_talib_8, CMO_talib_9, CMO_talib_10, CMO_talib_11, CMO_talib_12, CMO_talib_13, CMO_talib_14, CMO_talib_15, CMO_talib_16, CMO_talib_17, CMO_talib_18, CMO_talib_19, CMO_talib_20, MACD_ta_6, MACD_ta_7, MACD_ta_8, MACD_ta_9, MACD_ta_10, MACD_ta_11, MACD_ta_12, MACD_ta_13, MACD_ta_14, MACD_ta_15, MACD_ta_16, MACD_ta_17, MACD_ta_18, MACD_ta_19, MACD_ta_20, PPO_ta_6, PPO_ta_7, PPO_ta_8, PPO_ta_9, PPO_ta_10, PPO_ta_11, PPO_ta_12, PPO_ta_13, PPO_ta_14, PPO_ta_15, PPO_ta_16, PPO_ta_17, PPO_ta_18, PPO_ta_19, PPO_ta_20, ROC_ta_6, ROC_ta_7, ROC_ta_8, ROC_ta_9, ...]
# Index: []
#
# [0 rows x 226 columns]

# %%
common_cols=list(set.intersection(set(cleaned_df), set(features)))
X_features = cleaned_df[common_cols]

# rearrange to keep the original order of feature columns
feats = X_features[list(features.columns)]

feats.shape
# Out:
# (3894, 226)

# %%
# feats df contains features and label for all data
# feature columns
X = feats.iloc[:, feats.columns != 'Label']

# outcome column
y = feats.iloc[:, feats.columns == 'Label']

print("Shape of Features: ", X.values.shape)
print("Shape of Labels: ", y.values.shape)

X.head()
# Out:
# Shape of Features:  (3894, 225)
# Shape of Labels:  (3894, 1)
#      RSI_ta_6   RSI_ta_7   RSI_ta_8   RSI_ta_9  RSI_ta_10  RSI_ta_11  \
# 59  10.900907  13.984287  16.808864  19.335721  21.561469  23.502503
# 60   6.896011   9.373318  11.775636  14.029307  16.097933  17.969272
# 61  12.323443  14.017505  15.820532  17.601332  19.288652  20.847486
# 62  17.397102  18.306041  19.523081  20.849862  22.176042  23.441957
# 63  39.974992  37.884477  36.745996  36.181767  35.963598  35.950929
#
#     RSI_ta_12  RSI_ta_13  RSI_ta_14  RSI_ta_15  ...  TRIX_talib_13  \
# 59  25.184977  26.638602  27.893021  28.975873  ...      -0.029651
# 60  19.645962  21.139139  22.464201  23.638116  ...      -0.063217
# 61  22.264740  23.540211  24.680870  25.697282  ...      -0.097700
# 62  24.617978  25.692290  26.663413  27.535602  ...      -0.129928
# 63  36.056389  36.225617  36.425001  36.634057  ...      -0.154877
#
#     TRIX_talib_14  AWSM_ta_6  AWSM_ta_7  AWSM_ta_8  AWSM_ta_9  AWSM_ta_10  \
# 59      -0.018668  -1.855833  -1.797857  -1.737187  -1.515556    -1.30075
# 60      -0.047364  -2.082083  -2.159286  -2.083438  -1.968056    -1.74875
# 61      -0.077396  -2.351667  -2.343571  -2.408750  -2.348056    -2.19050
# 62      -0.106132  -2.400833  -2.513929  -2.540000  -2.587500    -2.48825
# 63      -0.129369  -2.191667  -2.506429  -2.553750  -2.599444    -2.66725
#
#     AWSM_ta_11  AWSM_ta_12  AWSM_ta_13
# 59   -1.007045   -0.709792   -0.436346
# 60   -1.432955   -1.107917   -0.837115
# 61   -1.928409   -1.534792   -1.239038
# 62   -2.335227   -1.991875   -1.582308
# 63   -2.545000   -2.361042   -1.959808
#
# [5 rows x 225 columns]

# %% [markdown]
# #Balance Classes

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.2-py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.4.0)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.12.2

# %%
import imblearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from collections import Counter

# encode labels for each class
def sampleDistribution(y):
  y = LabelEncoder().fit_transform(y)
  counter = Counter(y)

  for k,v in counter.items():
    per = v / len(y) * 100
    print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
  print("\n")

  bars = ('Hold', 'Buy', 'Sell')
  y_pos = np.arange(len(bars))

  plt.bar(counter.keys(), counter.values())
  plt.tick_params(axis='x', colors='red', direction='out', length=0, width=3)
  plt.xticks(np.arange(0, 3, 1))
  plt.xticks(y_pos, bars, color='black', rotation=0, fontweight='bold', fontsize='10', horizontalalignment='center')

print("Original Distribution of Samples in Each Class: ")
sampleDistribution(y)
# Out:
# Original Distribution of Samples in Each Class:
# Class=0, n=3399 (87.288%)
# Class=1, n=244 (6.266%)
# Class=2, n=251 (6.446%)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# Oversampling the Minority Class

# %%
# from imblearn.over_sampling import SMOTE
# oversample = SMOTE()
# # resample the dataset
# X_bal, y_bal = oversample.fit_resample(X, y)

# sampleDistribution(y_bal)

# X = pd.DataFrame(X_bal, columns = X.columns) # feature columns
# y = pd.DataFrame(y_bal, columns = y.columns) # oversampled label columns

# X.shape

# %% [markdown]
# Undersampling the Majority Class

# %%
# from imblearn.under_sampling import RandomUnderSampler
# # define undersample strategy
# undersample = RandomUnderSampler(sampling_strategy='majority')

# # fit and apply the transform
# X_bal, y_bal = undersample.fit_resample(X, y)

# sampleDistribution(y_bal)

# X = pd.DataFrame(X_bal, columns = X.columns) # feature columns
# y = pd.DataFrame(y_bal, columns = y.columns) # undersampled label columns

# X.shape

# %% [markdown]
# Combined Oversampling and Undersampling

# %%
# # from imblearn.under_sampling import RandomUnderSampler
# # from imblearn.over_sampling import RandomOverSampler

# from imblearn.combine import SMOTEENN, SMOTETomek
# # resample all but the majority class
# smote_tomek = SMOTETomek(sampling_strategy = 'not majority')

# # resample the dataset
# X_bal, y_bal = smote_tomek.fit_resample(X, y)

# sampleDistribution(y_bal)

# X = pd.DataFrame(X_bal, columns = X.columns) # undersample/oversampled feature columns
# y = pd.DataFrame(y_bal, columns = y.columns) # undersample/oversampled label columns

# X.shape
# Out:
# Class=0, n=4334 (33.333%)
# Class=1, n=4334 (33.333%)
# Class=2, n=4334 (33.333%)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (13002, 225)

# %% [markdown]
# Undersampling then Oversampling

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler


# define undersampling strategy
under = RandomUnderSampler(sampling_strategy={0:1250})

X_under, y_under = under.fit_resample(X, y)

# define oversampling strategy
over = RandomOverSampler(sampling_strategy = 'not majority')

X_bal, y_bal = over.fit_resample(X_under, y_under)

sampleDistribution(y_bal)

X = pd.DataFrame(X_bal, columns = X.columns)
y = pd.DataFrame(y_bal, columns = y.columns)

X.shape
# Out:
# Class=0, n=1250 (33.333%)
# Class=1, n=1250 (33.333%)
# Class=2, n=1250 (33.333%)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (3750, 225)

# %% [markdown]
# #Train Test Split

# %%
from sklearn.model_selection import train_test_split

# train and test data
X_train_set, X_test, y_train_set, y_test = train_test_split(X.values, y.values, train_size=0.8,
                                                    test_size=0.2, random_state=2, shuffle=True,
                                                    stratify=y.values)

print(f"X_train_set shape: {X_train_set.shape}")
print(f"y_train_set shape: {y_train_set.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train_set shape: (3000, 225)
# y_train_set shape: (3000, 1)
# X_test shape: (750, 225)
# y_test shape: (750, 1)

# %%
import numpy as np
unique, counts = np.unique(y_test, return_counts=True)
print("y_test Class Distribution: ")
print(np.asarray((unique, counts)).T)
# Out:
# y_test Class Distribution:
# [[  0 250]
#  [  1 250]
#  [  2 250]]

# %%
# train and validation data
X_train, X_val, y_train, y_val = train_test_split(X_train_set, y_train_set, train_size=0.8,
                                                    test_size=0.2, random_state=2, shuffle=True,
                                                    stratify=y_train_set)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# X_train shape: (2400, 225)
# y_train shape: (2400, 1)
# X_val shape: (600, 225)
# y_val shape: (600, 1)

# %%
import numpy as np
unique, counts = np.unique(y_val, return_counts=True)
print("y_val Class Distribution: ")
print(np.asarray((unique, counts)).T)
# Out:
# y_val Class Distribution:
# [[  0 200]
#  [  1 200]
#  [  2 200]]

# %%
import numpy as np
unique, counts = np.unique(y_train, return_counts=True)
print("y_train Class Distribution: ")
print(np.asarray((unique, counts)).T)
# Out:
# y_train Class Distribution:
# [[  0 800]
#  [  1 800]
#  [  2 800]]

# %% [markdown]
# # Setup Test Input Images (Normalizing + Encoding)

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# min max scalar
MM_SCALER = MinMaxScaler(feature_range=(-1, 1))

# One Hot Encode Labels
"""
0 -> [1, 0, 0]
1 -> [0, 1, 0]
2 -> [0, 0, 1]
"""
# Out:
# '\n0 -> [1, 0, 0]\n1 -> [0, 1, 0]\n2 -> [0, 0, 1]\n'

# %% [markdown]
# ###Normalize Data

# %%
X_train = MM_SCALER.fit_transform(X_train)
X_val = MM_SCALER.transform(X_val)
X_test = MM_SCALER.transform(X_test)

# %% [markdown]
# ###Reshape Data into 15x15 Images

# %%
X_train_images = X_train.reshape(X_train.shape[0], 15, 15)
X_val_images = X_val.reshape(X_val.shape[0], 15, 15)
X_test_images = X_test.reshape(X_test.shape[0], 15, 15)

print(f"X_train Images shape: {X_train_images.shape}")
print(f"X_val Images shape: {X_val_images.shape}")
print(f"X_test Images shape: {X_test_images.shape}")
# Out:
# X_train Images shape: (8320, 15, 15)
# X_val Images shape: (2081, 15, 15)
# X_test Images shape: (2601, 15, 15)

# %% [markdown]
# ###Encode Labels

# %%
OHE = OneHotEncoder(sparse=False, categories='auto')

y_train = OHE.fit_transform(y_train.reshape(-1, 1)) # Reshapes to a column vector
y_val = OHE.transform(y_val.reshape(-1, 1))
y_test = OHE.transform(y_test.reshape(-1, 1))

y_train.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# (8320, 3)

# %%
print(f"X_train Images shape: {X_train_images.shape}")
print(f"y_train labels shape: {y_train.shape}\n")

print(f"X_val Images shape: {X_val_images.shape}")
print(f"y_val labels shape: {y_val.shape}\n")

print(f"X_test Images shape: {X_test_images.shape}")
print(f"y_test labels shape: {y_test.shape}\n")
# Out:
# X_train Images shape: (8320, 15, 15)
# y_train labels shape: (8320, 3)
#
# X_val Images shape: (2081, 15, 15)
# y_val labels shape: (2081, 3)
#
# X_test Images shape: (2601, 15, 15)
# y_test labels shape: (2601, 3)

# %% [markdown]
# The trained model is evaluated on held-out data called the validation set.

# %% [markdown]
# #CNN

# %% [markdown]
# ###CNN Implementation

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

# !pip install h5py

params = {
    "input_w": 15,
    "input_h": 15,
    "input_c": 1,
    "num_classes": 3,
    "batch_size": 1024,
    "epochs": 1000
    }
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.25.2)

# %%
# CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(params["input_w"], params["input_h"], params["input_c"])))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(params["num_classes"], activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy', 'mae', 'mse'])

# %% [markdown]
# ###Model Checkpoint Callbacks

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, Callback

best_model_path = "data/4_best_model_keras.h5"
es = EarlyStopping(monitor='val_accuracy', mode='min', verbose=1,
                   patience=100, min_delta=0.0001) # Stops the training early when validation loss stops improving, prevent overfitting

rlp = ReduceLROnPlateau(monitor='val_loss', factor=0.02, patience=20, verbose=1, mode='min',
                        min_delta=0.001, cooldown=1, min_lr=0.0001) # Adjusts Learning Rate on validation loss

mcp = ModelCheckpoint(best_model_path, monitor='val_accuracy', verbose=1,
                      save_best_only=True, save_weights_only=False, mode='max', save_freq="epoch")  # val_f1_metric

# %% [markdown]
# ###Train CNN

# %%
# reshape input images to include a single channel to fit CNN Sequential Layer
X_train_images = np.expand_dims(X_train_images, axis=-1)
X_val_images = np.expand_dims(X_val_images, axis=-1)
X_test_images = np.expand_dims(X_test_images, axis=-1)

# %%
print(f"X_train Images shape: {X_train_images.shape}")
print(f"y_train labels shape: {y_train.shape}\n")

print(f"X_val Images shape: {X_val_images.shape}")
print(f"y_val labels shape: {y_val.shape}\n")

print(f"X_test Images shape: {X_test_images.shape}")
print(f"y_test labels shape: {y_test.shape}\n")
# Out:
# X_train Images shape: (8320, 15, 15, 1)
# y_train labels shape: (8320, 3)
#
# X_val Images shape: (2081, 15, 15, 1)
# y_val labels shape: (2081, 3)
#
# X_test Images shape: (2601, 15, 15, 1)
# y_test labels shape: (2601, 3)

# %%
# train CNN
hist = model.fit(X_train_images, y_train,
          batch_size=params["batch_size"],
          epochs=params["epochs"],
          callbacks=[mcp, rlp],
          validation_data = (X_val_images, y_val),
          verbose=2)
# Out:
# Epoch 1/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.1060 - accuracy: 0.3273 - mae: 0.4449 - mse: 0.2239
# Epoch 1: val_accuracy improved from -inf to 0.30082, saving model to data/4_best_model_keras.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 2s 101ms/step - loss: 1.1057 - accuracy: 0.3267 - mae: 0.4449 - mse: 0.2238 - val_loss: 1.1028 - val_accuracy: 0.3008 - val_mae: 0.4452 - val_mse: 0.2231 - lr: 0.0010
# Epoch 2/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.1051 - accuracy: 0.3226 - mae: 0.4447 - mse: 0.2237
# Epoch 2: val_accuracy improved from 0.30082 to 0.30418, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 53ms/step - loss: 1.1051 - accuracy: 0.3226 - mae: 0.4447 - mse: 0.2237 - val_loss: 1.1021 - val_accuracy: 0.3042 - val_mae: 0.4450 - val_mse: 0.2230 - lr: 0.0010
# Epoch 3/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1018 - accuracy: 0.3378 - mae: 0.4440 - mse: 0.2230
# Epoch 3: val_accuracy improved from 0.30418 to 0.30658, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 51ms/step - loss: 1.1020 - accuracy: 0.3373 - mae: 0.4441 - mse: 0.2230 - val_loss: 1.1015 - val_accuracy: 0.3066 - val_mae: 0.4449 - val_mse: 0.2229 - lr: 0.0010
# Epoch 4/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.1023 - accuracy: 0.3376 - mae: 0.4441 - mse: 0.2230
# Epoch 4: val_accuracy improved from 0.30658 to 0.30995, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.1023 - accuracy: 0.3370 - mae: 0.4442 - mse: 0.2231 - val_loss: 1.1008 - val_accuracy: 0.3099 - val_mae: 0.4447 - val_mse: 0.2227 - lr: 0.0010
# Epoch 5/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.1021 - accuracy: 0.3315 - mae: 0.4441 - mse: 0.2230
# Epoch 5: val_accuracy improved from 0.30995 to 0.31475, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 52ms/step - loss: 1.1021 - accuracy: 0.3315 - mae: 0.4441 - mse: 0.2230 - val_loss: 1.1002 - val_accuracy: 0.3148 - val_mae: 0.4446 - val_mse: 0.2226 - lr: 0.0010
# Epoch 6/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.1029 - accuracy: 0.3322 - mae: 0.4443 - mse: 0.2232
# Epoch 6: val_accuracy improved from 0.31475 to 0.31764, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.1028 - accuracy: 0.3322 - mae: 0.4443 - mse: 0.2232 - val_loss: 1.0995 - val_accuracy: 0.3176 - val_mae: 0.4444 - val_mse: 0.2224 - lr: 0.0010
# Epoch 7/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.1029 - accuracy: 0.3302 - mae: 0.4443 - mse: 0.2232
# Epoch 7: val_accuracy did not improve from 0.31764
# 9/9 [==============================] - 0s 42ms/step - loss: 1.1029 - accuracy: 0.3302 - mae: 0.4443 - mse: 0.2232 - val_loss: 1.0989 - val_accuracy: 0.3172 - val_mae: 0.4443 - val_mse: 0.2223 - lr: 0.0010
# Epoch 8/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.1009 - accuracy: 0.3410 - mae: 0.4438 - mse: 0.2228
# Epoch 8: val_accuracy improved from 0.31764 to 0.31908, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 51ms/step - loss: 1.1009 - accuracy: 0.3410 - mae: 0.4438 - mse: 0.2228 - val_loss: 1.0982 - val_accuracy: 0.3191 - val_mae: 0.4442 - val_mse: 0.2221 - lr: 0.0010
# Epoch 9/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0976 - accuracy: 0.3456 - mae: 0.4431 - mse: 0.2221
# Epoch 9: val_accuracy did not improve from 0.31908
# 9/9 [==============================] - 0s 43ms/step - loss: 1.0976 - accuracy: 0.3456 - mae: 0.4431 - mse: 0.2221 - val_loss: 1.0976 - val_accuracy: 0.3176 - val_mae: 0.4440 - val_mse: 0.2220 - lr: 0.0010
# Epoch 10/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0995 - accuracy: 0.3438 - mae: 0.4435 - mse: 0.2225
# Epoch 10: val_accuracy improved from 0.31908 to 0.32004, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0991 - accuracy: 0.3440 - mae: 0.4435 - mse: 0.2224 - val_loss: 1.0969 - val_accuracy: 0.3200 - val_mae: 0.4439 - val_mse: 0.2219 - lr: 0.0010
# Epoch 11/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0968 - accuracy: 0.3577 - mae: 0.4429 - mse: 0.2219
# Epoch 11: val_accuracy improved from 0.32004 to 0.32677, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0969 - accuracy: 0.3566 - mae: 0.4429 - mse: 0.2219 - val_loss: 1.0963 - val_accuracy: 0.3268 - val_mae: 0.4437 - val_mse: 0.2217 - lr: 0.0010
# Epoch 12/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0968 - accuracy: 0.3526 - mae: 0.4430 - mse: 0.2219
# Epoch 12: val_accuracy improved from 0.32677 to 0.33205, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0968 - accuracy: 0.3526 - mae: 0.4430 - mse: 0.2219 - val_loss: 1.0956 - val_accuracy: 0.3321 - val_mae: 0.4436 - val_mse: 0.2216 - lr: 0.0010
# Epoch 13/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0981 - accuracy: 0.3433 - mae: 0.4433 - mse: 0.2222
# Epoch 13: val_accuracy improved from 0.33205 to 0.33734, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0981 - accuracy: 0.3433 - mae: 0.4433 - mse: 0.2222 - val_loss: 1.0949 - val_accuracy: 0.3373 - val_mae: 0.4434 - val_mse: 0.2214 - lr: 0.0010
# Epoch 14/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0971 - accuracy: 0.3505 - mae: 0.4430 - mse: 0.2219
# Epoch 14: val_accuracy improved from 0.33734 to 0.34358, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0971 - accuracy: 0.3505 - mae: 0.4430 - mse: 0.2219 - val_loss: 1.0942 - val_accuracy: 0.3436 - val_mae: 0.4433 - val_mse: 0.2213 - lr: 0.0010
# Epoch 15/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0958 - accuracy: 0.3496 - mae: 0.4427 - mse: 0.2217
# Epoch 15: val_accuracy did not improve from 0.34358
# 9/9 [==============================] - 0s 45ms/step - loss: 1.0958 - accuracy: 0.3496 - mae: 0.4427 - mse: 0.2217 - val_loss: 1.0936 - val_accuracy: 0.3436 - val_mae: 0.4431 - val_mse: 0.2211 - lr: 0.0010
# Epoch 16/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0962 - accuracy: 0.3513 - mae: 0.4428 - mse: 0.2217
# Epoch 16: val_accuracy improved from 0.34358 to 0.34839, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0963 - accuracy: 0.3522 - mae: 0.4428 - mse: 0.2217 - val_loss: 1.0929 - val_accuracy: 0.3484 - val_mae: 0.4430 - val_mse: 0.2210 - lr: 0.0010
# Epoch 17/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0957 - accuracy: 0.3530 - mae: 0.4427 - mse: 0.2216
# Epoch 17: val_accuracy improved from 0.34839 to 0.35464, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0950 - accuracy: 0.3544 - mae: 0.4425 - mse: 0.2215 - val_loss: 1.0922 - val_accuracy: 0.3546 - val_mae: 0.4428 - val_mse: 0.2208 - lr: 0.0010
# Epoch 18/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0947 - accuracy: 0.3524 - mae: 0.4425 - mse: 0.2214
# Epoch 18: val_accuracy improved from 0.35464 to 0.35944, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 1.0943 - accuracy: 0.3542 - mae: 0.4424 - mse: 0.2213 - val_loss: 1.0916 - val_accuracy: 0.3594 - val_mae: 0.4427 - val_mse: 0.2207 - lr: 0.0010
# Epoch 19/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0963 - accuracy: 0.3482 - mae: 0.4429 - mse: 0.2218
# Epoch 19: val_accuracy did not improve from 0.35944
# 9/9 [==============================] - 0s 44ms/step - loss: 1.0963 - accuracy: 0.3482 - mae: 0.4429 - mse: 0.2218 - val_loss: 1.0909 - val_accuracy: 0.3594 - val_mae: 0.4425 - val_mse: 0.2205 - lr: 0.0010
# Epoch 20/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0952 - accuracy: 0.3464 - mae: 0.4426 - mse: 0.2215
# Epoch 20: val_accuracy improved from 0.35944 to 0.35992, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0950 - accuracy: 0.3476 - mae: 0.4426 - mse: 0.2215 - val_loss: 1.0902 - val_accuracy: 0.3599 - val_mae: 0.4424 - val_mse: 0.2204 - lr: 0.0010
# Epoch 21/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0935 - accuracy: 0.3595 - mae: 0.4423 - mse: 0.2212
# Epoch 21: val_accuracy improved from 0.35992 to 0.36329, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0931 - accuracy: 0.3611 - mae: 0.4422 - mse: 0.2211 - val_loss: 1.0896 - val_accuracy: 0.3633 - val_mae: 0.4422 - val_mse: 0.2203 - lr: 0.0010
# Epoch 22/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0932 - accuracy: 0.3600 - mae: 0.4422 - mse: 0.2211
# Epoch 22: val_accuracy improved from 0.36329 to 0.36713, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0932 - accuracy: 0.3600 - mae: 0.4422 - mse: 0.2211 - val_loss: 1.0889 - val_accuracy: 0.3671 - val_mae: 0.4421 - val_mse: 0.2201 - lr: 0.0010
# Epoch 23/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0899 - accuracy: 0.3714 - mae: 0.4414 - mse: 0.2203
# Epoch 23: val_accuracy improved from 0.36713 to 0.37146, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0904 - accuracy: 0.3697 - mae: 0.4415 - mse: 0.2204 - val_loss: 1.0882 - val_accuracy: 0.3715 - val_mae: 0.4419 - val_mse: 0.2200 - lr: 0.0010
# Epoch 24/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0928 - accuracy: 0.3627 - mae: 0.4421 - mse: 0.2210
# Epoch 24: val_accuracy improved from 0.37146 to 0.37386, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0924 - accuracy: 0.3651 - mae: 0.4420 - mse: 0.2209 - val_loss: 1.0875 - val_accuracy: 0.3739 - val_mae: 0.4418 - val_mse: 0.2198 - lr: 0.0010
# Epoch 25/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0917 - accuracy: 0.3624 - mae: 0.4418 - mse: 0.2208
# Epoch 25: val_accuracy improved from 0.37386 to 0.37530, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0917 - accuracy: 0.3624 - mae: 0.4418 - mse: 0.2208 - val_loss: 1.0868 - val_accuracy: 0.3753 - val_mae: 0.4416 - val_mse: 0.2197 - lr: 0.0010
# Epoch 26/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0912 - accuracy: 0.3630 - mae: 0.4417 - mse: 0.2206
# Epoch 26: val_accuracy improved from 0.37530 to 0.37674, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0908 - accuracy: 0.3665 - mae: 0.4416 - mse: 0.2205 - val_loss: 1.0862 - val_accuracy: 0.3767 - val_mae: 0.4415 - val_mse: 0.2195 - lr: 0.0010
# Epoch 27/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0910 - accuracy: 0.3655 - mae: 0.4417 - mse: 0.2206
# Epoch 27: val_accuracy improved from 0.37674 to 0.37818, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 51ms/step - loss: 1.0910 - accuracy: 0.3655 - mae: 0.4417 - mse: 0.2206 - val_loss: 1.0855 - val_accuracy: 0.3782 - val_mae: 0.4413 - val_mse: 0.2194 - lr: 0.0010
# Epoch 28/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0896 - accuracy: 0.3760 - mae: 0.4413 - mse: 0.2203
# Epoch 28: val_accuracy improved from 0.37818 to 0.38203, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 1.0891 - accuracy: 0.3779 - mae: 0.4412 - mse: 0.2202 - val_loss: 1.0848 - val_accuracy: 0.3820 - val_mae: 0.4411 - val_mse: 0.2192 - lr: 0.0010
# Epoch 29/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0860 - accuracy: 0.3845 - mae: 0.4405 - mse: 0.2195
# Epoch 29: val_accuracy improved from 0.38203 to 0.38683, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0860 - accuracy: 0.3845 - mae: 0.4405 - mse: 0.2195 - val_loss: 1.0842 - val_accuracy: 0.3868 - val_mae: 0.4410 - val_mse: 0.2191 - lr: 0.0010
# Epoch 30/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0880 - accuracy: 0.3805 - mae: 0.4410 - mse: 0.2199
# Epoch 30: val_accuracy improved from 0.38683 to 0.38924, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0880 - accuracy: 0.3805 - mae: 0.4410 - mse: 0.2199 - val_loss: 1.0835 - val_accuracy: 0.3892 - val_mae: 0.4408 - val_mse: 0.2189 - lr: 0.0010
# Epoch 31/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0887 - accuracy: 0.3802 - mae: 0.4411 - mse: 0.2201
# Epoch 31: val_accuracy improved from 0.38924 to 0.39212, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0887 - accuracy: 0.3802 - mae: 0.4411 - mse: 0.2201 - val_loss: 1.0829 - val_accuracy: 0.3921 - val_mae: 0.4407 - val_mse: 0.2188 - lr: 0.0010
# Epoch 32/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0867 - accuracy: 0.3810 - mae: 0.4407 - mse: 0.2197
# Epoch 32: val_accuracy improved from 0.39212 to 0.39548, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0870 - accuracy: 0.3785 - mae: 0.4407 - mse: 0.2197 - val_loss: 1.0822 - val_accuracy: 0.3955 - val_mae: 0.4405 - val_mse: 0.2186 - lr: 0.0010
# Epoch 33/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0847 - accuracy: 0.3889 - mae: 0.4402 - mse: 0.2192
# Epoch 33: val_accuracy improved from 0.39548 to 0.40269, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0847 - accuracy: 0.3889 - mae: 0.4402 - mse: 0.2192 - val_loss: 1.0815 - val_accuracy: 0.4027 - val_mae: 0.4404 - val_mse: 0.2185 - lr: 0.0010
# Epoch 34/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0855 - accuracy: 0.3849 - mae: 0.4404 - mse: 0.2194
# Epoch 34: val_accuracy improved from 0.40269 to 0.40557, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0855 - accuracy: 0.3849 - mae: 0.4404 - mse: 0.2194 - val_loss: 1.0809 - val_accuracy: 0.4056 - val_mae: 0.4402 - val_mse: 0.2183 - lr: 0.0010
# Epoch 35/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0851 - accuracy: 0.3881 - mae: 0.4403 - mse: 0.2193
# Epoch 35: val_accuracy improved from 0.40557 to 0.40942, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0851 - accuracy: 0.3881 - mae: 0.4403 - mse: 0.2193 - val_loss: 1.0802 - val_accuracy: 0.4094 - val_mae: 0.4401 - val_mse: 0.2182 - lr: 0.0010
# Epoch 36/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0824 - accuracy: 0.3990 - mae: 0.4397 - mse: 0.2187
# Epoch 36: val_accuracy improved from 0.40942 to 0.41230, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0829 - accuracy: 0.3963 - mae: 0.4398 - mse: 0.2188 - val_loss: 1.0795 - val_accuracy: 0.4123 - val_mae: 0.4399 - val_mse: 0.2180 - lr: 0.0010
# Epoch 37/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0831 - accuracy: 0.3955 - mae: 0.4399 - mse: 0.2189
# Epoch 37: val_accuracy improved from 0.41230 to 0.41663, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0829 - accuracy: 0.3966 - mae: 0.4398 - mse: 0.2188 - val_loss: 1.0789 - val_accuracy: 0.4166 - val_mae: 0.4398 - val_mse: 0.2179 - lr: 0.0010
# Epoch 38/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0828 - accuracy: 0.3951 - mae: 0.4398 - mse: 0.2188
# Epoch 38: val_accuracy improved from 0.41663 to 0.42191, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0828 - accuracy: 0.3951 - mae: 0.4398 - mse: 0.2188 - val_loss: 1.0782 - val_accuracy: 0.4219 - val_mae: 0.4396 - val_mse: 0.2177 - lr: 0.0010
# Epoch 39/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0820 - accuracy: 0.4014 - mae: 0.4396 - mse: 0.2186
# Epoch 39: val_accuracy improved from 0.42191 to 0.42432, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0820 - accuracy: 0.3981 - mae: 0.4396 - mse: 0.2186 - val_loss: 1.0775 - val_accuracy: 0.4243 - val_mae: 0.4394 - val_mse: 0.2176 - lr: 0.0010
# Epoch 40/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0811 - accuracy: 0.3997 - mae: 0.4394 - mse: 0.2184
# Epoch 40: val_accuracy improved from 0.42432 to 0.42864, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0815 - accuracy: 0.3988 - mae: 0.4395 - mse: 0.2185 - val_loss: 1.0769 - val_accuracy: 0.4286 - val_mae: 0.4393 - val_mse: 0.2175 - lr: 0.0010
# Epoch 41/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0817 - accuracy: 0.4030 - mae: 0.4395 - mse: 0.2185
# Epoch 41: val_accuracy improved from 0.42864 to 0.42960, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0810 - accuracy: 0.4055 - mae: 0.4394 - mse: 0.2184 - val_loss: 1.0762 - val_accuracy: 0.4296 - val_mae: 0.4391 - val_mse: 0.2173 - lr: 0.0010
# Epoch 42/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0808 - accuracy: 0.3963 - mae: 0.4393 - mse: 0.2184
# Epoch 42: val_accuracy improved from 0.42960 to 0.43345, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0804 - accuracy: 0.3994 - mae: 0.4392 - mse: 0.2183 - val_loss: 1.0755 - val_accuracy: 0.4334 - val_mae: 0.4390 - val_mse: 0.2172 - lr: 0.0010
# Epoch 43/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0801 - accuracy: 0.3955 - mae: 0.4392 - mse: 0.2182
# Epoch 43: val_accuracy improved from 0.43345 to 0.44065, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0805 - accuracy: 0.3952 - mae: 0.4393 - mse: 0.2183 - val_loss: 1.0749 - val_accuracy: 0.4407 - val_mae: 0.4388 - val_mse: 0.2170 - lr: 0.0010
# Epoch 44/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0791 - accuracy: 0.4054 - mae: 0.4389 - mse: 0.2180
# Epoch 44: val_accuracy improved from 0.44065 to 0.44258, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 51ms/step - loss: 1.0791 - accuracy: 0.4054 - mae: 0.4389 - mse: 0.2180 - val_loss: 1.0742 - val_accuracy: 0.4426 - val_mae: 0.4387 - val_mse: 0.2169 - lr: 0.0010
# Epoch 45/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0792 - accuracy: 0.4026 - mae: 0.4390 - mse: 0.2180
# Epoch 45: val_accuracy improved from 0.44258 to 0.44786, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 53ms/step - loss: 1.0792 - accuracy: 0.4026 - mae: 0.4390 - mse: 0.2180 - val_loss: 1.0736 - val_accuracy: 0.4479 - val_mae: 0.4385 - val_mse: 0.2167 - lr: 0.0010
# Epoch 46/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0799 - accuracy: 0.4043 - mae: 0.4391 - mse: 0.2181
# Epoch 46: val_accuracy improved from 0.44786 to 0.45315, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 1.0793 - accuracy: 0.4052 - mae: 0.4389 - mse: 0.2180 - val_loss: 1.0729 - val_accuracy: 0.4531 - val_mae: 0.4383 - val_mse: 0.2166 - lr: 0.0010
# Epoch 47/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0790 - accuracy: 0.3978 - mae: 0.4389 - mse: 0.2180
# Epoch 47: val_accuracy improved from 0.45315 to 0.45747, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 51ms/step - loss: 1.0790 - accuracy: 0.3978 - mae: 0.4389 - mse: 0.2180 - val_loss: 1.0722 - val_accuracy: 0.4575 - val_mae: 0.4382 - val_mse: 0.2164 - lr: 0.0010
# Epoch 48/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0755 - accuracy: 0.4224 - mae: 0.4381 - mse: 0.2172
# Epoch 48: val_accuracy improved from 0.45747 to 0.45988, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0758 - accuracy: 0.4212 - mae: 0.4382 - mse: 0.2172 - val_loss: 1.0716 - val_accuracy: 0.4599 - val_mae: 0.4380 - val_mse: 0.2163 - lr: 0.0010
# Epoch 49/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0758 - accuracy: 0.4103 - mae: 0.4382 - mse: 0.2173
# Epoch 49: val_accuracy improved from 0.45988 to 0.46276, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0764 - accuracy: 0.4066 - mae: 0.4383 - mse: 0.2174 - val_loss: 1.0709 - val_accuracy: 0.4628 - val_mae: 0.4379 - val_mse: 0.2161 - lr: 0.0010
# Epoch 50/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0766 - accuracy: 0.4178 - mae: 0.4384 - mse: 0.2174
# Epoch 50: val_accuracy improved from 0.46276 to 0.46660, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 52ms/step - loss: 1.0766 - accuracy: 0.4178 - mae: 0.4384 - mse: 0.2174 - val_loss: 1.0702 - val_accuracy: 0.4666 - val_mae: 0.4377 - val_mse: 0.2160 - lr: 0.0010
# Epoch 51/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0760 - accuracy: 0.4103 - mae: 0.4382 - mse: 0.2173
# Epoch 51: val_accuracy improved from 0.46660 to 0.46901, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0762 - accuracy: 0.4126 - mae: 0.4382 - mse: 0.2173 - val_loss: 1.0696 - val_accuracy: 0.4690 - val_mae: 0.4375 - val_mse: 0.2158 - lr: 0.0010
# Epoch 52/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0760 - accuracy: 0.4114 - mae: 0.4382 - mse: 0.2173
# Epoch 52: val_accuracy improved from 0.46901 to 0.47285, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0763 - accuracy: 0.4101 - mae: 0.4382 - mse: 0.2174 - val_loss: 1.0689 - val_accuracy: 0.4728 - val_mae: 0.4374 - val_mse: 0.2157 - lr: 0.0010
# Epoch 53/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0728 - accuracy: 0.4227 - mae: 0.4375 - mse: 0.2166
# Epoch 53: val_accuracy improved from 0.47285 to 0.47669, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0728 - accuracy: 0.4227 - mae: 0.4375 - mse: 0.2166 - val_loss: 1.0683 - val_accuracy: 0.4767 - val_mae: 0.4372 - val_mse: 0.2155 - lr: 0.0010
# Epoch 54/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0719 - accuracy: 0.4286 - mae: 0.4372 - mse: 0.2164
# Epoch 54: val_accuracy improved from 0.47669 to 0.47958, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0719 - accuracy: 0.4276 - mae: 0.4373 - mse: 0.2164 - val_loss: 1.0676 - val_accuracy: 0.4796 - val_mae: 0.4371 - val_mse: 0.2154 - lr: 0.0010
# Epoch 55/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0735 - accuracy: 0.4224 - mae: 0.4376 - mse: 0.2167
# Epoch 55: val_accuracy improved from 0.47958 to 0.48150, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0735 - accuracy: 0.4224 - mae: 0.4376 - mse: 0.2167 - val_loss: 1.0670 - val_accuracy: 0.4815 - val_mae: 0.4369 - val_mse: 0.2153 - lr: 0.0010
# Epoch 56/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0699 - accuracy: 0.4360 - mae: 0.4368 - mse: 0.2159
# Epoch 56: val_accuracy improved from 0.48150 to 0.48294, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0702 - accuracy: 0.4339 - mae: 0.4368 - mse: 0.2160 - val_loss: 1.0663 - val_accuracy: 0.4829 - val_mae: 0.4368 - val_mse: 0.2151 - lr: 0.0010
# Epoch 57/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0725 - accuracy: 0.4198 - mae: 0.4374 - mse: 0.2166
# Epoch 57: val_accuracy improved from 0.48294 to 0.48342, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 51ms/step - loss: 1.0725 - accuracy: 0.4198 - mae: 0.4374 - mse: 0.2166 - val_loss: 1.0657 - val_accuracy: 0.4834 - val_mae: 0.4366 - val_mse: 0.2150 - lr: 0.0010
# Epoch 58/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0710 - accuracy: 0.4313 - mae: 0.4370 - mse: 0.2162
# Epoch 58: val_accuracy improved from 0.48342 to 0.48630, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 56ms/step - loss: 1.0710 - accuracy: 0.4313 - mae: 0.4370 - mse: 0.2162 - val_loss: 1.0650 - val_accuracy: 0.4863 - val_mae: 0.4364 - val_mse: 0.2148 - lr: 0.0010
# Epoch 59/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0690 - accuracy: 0.4368 - mae: 0.4366 - mse: 0.2158
# Epoch 59: val_accuracy improved from 0.48630 to 0.48967, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0695 - accuracy: 0.4343 - mae: 0.4367 - mse: 0.2159 - val_loss: 1.0644 - val_accuracy: 0.4897 - val_mae: 0.4363 - val_mse: 0.2147 - lr: 0.0010
# Epoch 60/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0686 - accuracy: 0.4337 - mae: 0.4364 - mse: 0.2157
# Epoch 60: val_accuracy improved from 0.48967 to 0.49063, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0694 - accuracy: 0.4323 - mae: 0.4366 - mse: 0.2158 - val_loss: 1.0637 - val_accuracy: 0.4906 - val_mae: 0.4361 - val_mse: 0.2145 - lr: 0.0010
# Epoch 61/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0696 - accuracy: 0.4294 - mae: 0.4366 - mse: 0.2159
# Epoch 61: val_accuracy improved from 0.49063 to 0.49303, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0696 - accuracy: 0.4315 - mae: 0.4367 - mse: 0.2159 - val_loss: 1.0631 - val_accuracy: 0.4930 - val_mae: 0.4360 - val_mse: 0.2144 - lr: 0.0010
# Epoch 62/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0680 - accuracy: 0.4386 - mae: 0.4363 - mse: 0.2155
# Epoch 62: val_accuracy improved from 0.49303 to 0.49447, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0683 - accuracy: 0.4370 - mae: 0.4364 - mse: 0.2156 - val_loss: 1.0624 - val_accuracy: 0.4945 - val_mae: 0.4358 - val_mse: 0.2142 - lr: 0.0010
# Epoch 63/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0678 - accuracy: 0.4311 - mae: 0.4363 - mse: 0.2155
# Epoch 63: val_accuracy improved from 0.49447 to 0.49880, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0678 - accuracy: 0.4311 - mae: 0.4363 - mse: 0.2155 - val_loss: 1.0617 - val_accuracy: 0.4988 - val_mae: 0.4356 - val_mse: 0.2141 - lr: 0.0010
# Epoch 64/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0662 - accuracy: 0.4488 - mae: 0.4359 - mse: 0.2151
# Epoch 64: val_accuracy improved from 0.49880 to 0.50553, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0662 - accuracy: 0.4488 - mae: 0.4359 - mse: 0.2151 - val_loss: 1.0611 - val_accuracy: 0.5055 - val_mae: 0.4355 - val_mse: 0.2139 - lr: 0.0010
# Epoch 65/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0673 - accuracy: 0.4349 - mae: 0.4361 - mse: 0.2154
# Epoch 65: val_accuracy improved from 0.50553 to 0.50889, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0673 - accuracy: 0.4349 - mae: 0.4361 - mse: 0.2154 - val_loss: 1.0604 - val_accuracy: 0.5089 - val_mae: 0.4353 - val_mse: 0.2138 - lr: 0.0010
# Epoch 66/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0671 - accuracy: 0.4392 - mae: 0.4360 - mse: 0.2153
# Epoch 66: val_accuracy improved from 0.50889 to 0.51273, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0671 - accuracy: 0.4392 - mae: 0.4360 - mse: 0.2153 - val_loss: 1.0598 - val_accuracy: 0.5127 - val_mae: 0.4352 - val_mse: 0.2137 - lr: 0.0010
# Epoch 67/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0661 - accuracy: 0.4424 - mae: 0.4358 - mse: 0.2151
# Epoch 67: val_accuracy improved from 0.51273 to 0.51706, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0663 - accuracy: 0.4460 - mae: 0.4359 - mse: 0.2152 - val_loss: 1.0591 - val_accuracy: 0.5171 - val_mae: 0.4350 - val_mse: 0.2135 - lr: 0.0010
# Epoch 68/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0645 - accuracy: 0.4476 - mae: 0.4354 - mse: 0.2148
# Epoch 68: val_accuracy improved from 0.51706 to 0.51850, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0645 - accuracy: 0.4476 - mae: 0.4354 - mse: 0.2148 - val_loss: 1.0585 - val_accuracy: 0.5185 - val_mae: 0.4348 - val_mse: 0.2134 - lr: 0.0010
# Epoch 69/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0658 - accuracy: 0.4375 - mae: 0.4357 - mse: 0.2151
# Epoch 69: val_accuracy improved from 0.51850 to 0.51946, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0658 - accuracy: 0.4375 - mae: 0.4357 - mse: 0.2151 - val_loss: 1.0579 - val_accuracy: 0.5195 - val_mae: 0.4347 - val_mse: 0.2132 - lr: 0.0010
# Epoch 70/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0649 - accuracy: 0.4456 - mae: 0.4355 - mse: 0.2148
# Epoch 70: val_accuracy improved from 0.51946 to 0.52090, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0645 - accuracy: 0.4475 - mae: 0.4354 - mse: 0.2147 - val_loss: 1.0572 - val_accuracy: 0.5209 - val_mae: 0.4345 - val_mse: 0.2131 - lr: 0.0010
# Epoch 71/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0639 - accuracy: 0.4534 - mae: 0.4353 - mse: 0.2146
# Epoch 71: val_accuracy improved from 0.52090 to 0.52667, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0632 - accuracy: 0.4558 - mae: 0.4351 - mse: 0.2145 - val_loss: 1.0565 - val_accuracy: 0.5267 - val_mae: 0.4344 - val_mse: 0.2129 - lr: 0.0010
# Epoch 72/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0622 - accuracy: 0.4510 - mae: 0.4349 - mse: 0.2142
# Epoch 72: val_accuracy improved from 0.52667 to 0.53099, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0622 - accuracy: 0.4510 - mae: 0.4349 - mse: 0.2142 - val_loss: 1.0559 - val_accuracy: 0.5310 - val_mae: 0.4342 - val_mse: 0.2128 - lr: 0.0010
# Epoch 73/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0619 - accuracy: 0.4467 - mae: 0.4348 - mse: 0.2142
# Epoch 73: val_accuracy improved from 0.53099 to 0.53340, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0621 - accuracy: 0.4442 - mae: 0.4348 - mse: 0.2142 - val_loss: 1.0553 - val_accuracy: 0.5334 - val_mae: 0.4340 - val_mse: 0.2127 - lr: 0.0010
# Epoch 74/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0617 - accuracy: 0.4586 - mae: 0.4347 - mse: 0.2141
# Epoch 74: val_accuracy improved from 0.53340 to 0.53772, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0608 - accuracy: 0.4588 - mae: 0.4346 - mse: 0.2140 - val_loss: 1.0546 - val_accuracy: 0.5377 - val_mae: 0.4339 - val_mse: 0.2125 - lr: 0.0010
# Epoch 75/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0589 - accuracy: 0.4648 - mae: 0.4341 - mse: 0.2135
# Epoch 75: val_accuracy improved from 0.53772 to 0.54253, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 53ms/step - loss: 1.0591 - accuracy: 0.4638 - mae: 0.4341 - mse: 0.2136 - val_loss: 1.0540 - val_accuracy: 0.5425 - val_mae: 0.4337 - val_mse: 0.2124 - lr: 0.0010
# Epoch 76/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0604 - accuracy: 0.4566 - mae: 0.4344 - mse: 0.2139
# Epoch 76: val_accuracy improved from 0.54253 to 0.54541, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0604 - accuracy: 0.4566 - mae: 0.4344 - mse: 0.2139 - val_loss: 1.0534 - val_accuracy: 0.5454 - val_mae: 0.4336 - val_mse: 0.2122 - lr: 0.0010
# Epoch 77/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0590 - accuracy: 0.4582 - mae: 0.4341 - mse: 0.2135
# Epoch 77: val_accuracy did not improve from 0.54541
# 9/9 [==============================] - 0s 46ms/step - loss: 1.0590 - accuracy: 0.4582 - mae: 0.4341 - mse: 0.2135 - val_loss: 1.0527 - val_accuracy: 0.5449 - val_mae: 0.4334 - val_mse: 0.2121 - lr: 0.0010
# Epoch 78/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0597 - accuracy: 0.4622 - mae: 0.4342 - mse: 0.2137
# Epoch 78: val_accuracy improved from 0.54541 to 0.54733, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 1.0589 - accuracy: 0.4633 - mae: 0.4341 - mse: 0.2135 - val_loss: 1.0521 - val_accuracy: 0.5473 - val_mae: 0.4332 - val_mse: 0.2119 - lr: 0.0010
# Epoch 79/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0583 - accuracy: 0.4725 - mae: 0.4339 - mse: 0.2134
# Epoch 79: val_accuracy improved from 0.54733 to 0.54781, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0579 - accuracy: 0.4743 - mae: 0.4338 - mse: 0.2133 - val_loss: 1.0514 - val_accuracy: 0.5478 - val_mae: 0.4331 - val_mse: 0.2118 - lr: 0.0010
# Epoch 80/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0577 - accuracy: 0.4720 - mae: 0.4337 - mse: 0.2132
# Epoch 80: val_accuracy improved from 0.54781 to 0.55070, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0577 - accuracy: 0.4720 - mae: 0.4337 - mse: 0.2132 - val_loss: 1.0508 - val_accuracy: 0.5507 - val_mae: 0.4329 - val_mse: 0.2116 - lr: 0.0010
# Epoch 81/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0566 - accuracy: 0.4771 - mae: 0.4335 - mse: 0.2130
# Epoch 81: val_accuracy improved from 0.55070 to 0.55118, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0570 - accuracy: 0.4724 - mae: 0.4336 - mse: 0.2131 - val_loss: 1.0501 - val_accuracy: 0.5512 - val_mae: 0.4328 - val_mse: 0.2115 - lr: 0.0010
# Epoch 82/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0552 - accuracy: 0.4709 - mae: 0.4332 - mse: 0.2127
# Epoch 82: val_accuracy improved from 0.55118 to 0.55454, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0552 - accuracy: 0.4709 - mae: 0.4332 - mse: 0.2127 - val_loss: 1.0495 - val_accuracy: 0.5545 - val_mae: 0.4326 - val_mse: 0.2114 - lr: 0.0010
# Epoch 83/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0550 - accuracy: 0.4707 - mae: 0.4331 - mse: 0.2126
# Epoch 83: val_accuracy improved from 0.55454 to 0.55694, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 1.0547 - accuracy: 0.4725 - mae: 0.4330 - mse: 0.2126 - val_loss: 1.0488 - val_accuracy: 0.5569 - val_mae: 0.4324 - val_mse: 0.2112 - lr: 0.0010
# Epoch 84/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0551 - accuracy: 0.4681 - mae: 0.4332 - mse: 0.2127
# Epoch 84: val_accuracy improved from 0.55694 to 0.56079, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 45ms/step - loss: 1.0552 - accuracy: 0.4703 - mae: 0.4332 - mse: 0.2127 - val_loss: 1.0482 - val_accuracy: 0.5608 - val_mae: 0.4323 - val_mse: 0.2111 - lr: 0.0010
# Epoch 85/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0564 - accuracy: 0.4707 - mae: 0.4335 - mse: 0.2130
# Epoch 85: val_accuracy improved from 0.56079 to 0.56367, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 1s 59ms/step - loss: 1.0564 - accuracy: 0.4707 - mae: 0.4335 - mse: 0.2130 - val_loss: 1.0475 - val_accuracy: 0.5637 - val_mae: 0.4321 - val_mse: 0.2109 - lr: 0.0010
# Epoch 86/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0548 - accuracy: 0.4708 - mae: 0.4330 - mse: 0.2126
# Epoch 86: val_accuracy improved from 0.56367 to 0.56655, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0548 - accuracy: 0.4708 - mae: 0.4330 - mse: 0.2126 - val_loss: 1.0469 - val_accuracy: 0.5666 - val_mae: 0.4320 - val_mse: 0.2108 - lr: 0.0010
# Epoch 87/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0530 - accuracy: 0.4832 - mae: 0.4326 - mse: 0.2122
# Epoch 87: val_accuracy improved from 0.56655 to 0.56944, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0530 - accuracy: 0.4832 - mae: 0.4326 - mse: 0.2122 - val_loss: 1.0463 - val_accuracy: 0.5694 - val_mae: 0.4318 - val_mse: 0.2106 - lr: 0.0010
# Epoch 88/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0515 - accuracy: 0.4811 - mae: 0.4323 - mse: 0.2119
# Epoch 88: val_accuracy improved from 0.56944 to 0.57424, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0515 - accuracy: 0.4811 - mae: 0.4323 - mse: 0.2119 - val_loss: 1.0456 - val_accuracy: 0.5742 - val_mae: 0.4316 - val_mse: 0.2105 - lr: 0.0010
# Epoch 89/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0534 - accuracy: 0.4808 - mae: 0.4326 - mse: 0.2123
# Epoch 89: val_accuracy improved from 0.57424 to 0.57568, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 52ms/step - loss: 1.0534 - accuracy: 0.4808 - mae: 0.4326 - mse: 0.2123 - val_loss: 1.0450 - val_accuracy: 0.5757 - val_mae: 0.4315 - val_mse: 0.2103 - lr: 0.0010
# Epoch 90/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0539 - accuracy: 0.4822 - mae: 0.4328 - mse: 0.2124
# Epoch 90: val_accuracy improved from 0.57568 to 0.57617, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0539 - accuracy: 0.4822 - mae: 0.4328 - mse: 0.2124 - val_loss: 1.0443 - val_accuracy: 0.5762 - val_mae: 0.4313 - val_mse: 0.2102 - lr: 0.0010
# Epoch 91/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0518 - accuracy: 0.4777 - mae: 0.4323 - mse: 0.2120
# Epoch 91: val_accuracy improved from 0.57617 to 0.57905, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 51ms/step - loss: 1.0510 - accuracy: 0.4794 - mae: 0.4321 - mse: 0.2118 - val_loss: 1.0437 - val_accuracy: 0.5790 - val_mae: 0.4311 - val_mse: 0.2101 - lr: 0.0010
# Epoch 92/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0497 - accuracy: 0.4814 - mae: 0.4318 - mse: 0.2115
# Epoch 92: val_accuracy improved from 0.57905 to 0.58097, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0502 - accuracy: 0.4817 - mae: 0.4319 - mse: 0.2116 - val_loss: 1.0430 - val_accuracy: 0.5810 - val_mae: 0.4310 - val_mse: 0.2099 - lr: 0.0010
# Epoch 93/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0476 - accuracy: 0.4950 - mae: 0.4313 - mse: 0.2110
# Epoch 93: val_accuracy improved from 0.58097 to 0.58337, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0476 - accuracy: 0.4950 - mae: 0.4313 - mse: 0.2110 - val_loss: 1.0424 - val_accuracy: 0.5834 - val_mae: 0.4308 - val_mse: 0.2098 - lr: 0.0010
# Epoch 94/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0510 - accuracy: 0.4849 - mae: 0.4321 - mse: 0.2118
# Epoch 94: val_accuracy improved from 0.58337 to 0.58385, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0508 - accuracy: 0.4855 - mae: 0.4321 - mse: 0.2117 - val_loss: 1.0417 - val_accuracy: 0.5839 - val_mae: 0.4306 - val_mse: 0.2096 - lr: 0.0010
# Epoch 95/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0495 - accuracy: 0.4855 - mae: 0.4316 - mse: 0.2114
# Epoch 95: val_accuracy improved from 0.58385 to 0.58481, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0495 - accuracy: 0.4855 - mae: 0.4316 - mse: 0.2114 - val_loss: 1.0411 - val_accuracy: 0.5848 - val_mae: 0.4305 - val_mse: 0.2095 - lr: 0.0010
# Epoch 96/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0485 - accuracy: 0.4856 - mae: 0.4314 - mse: 0.2112
# Epoch 96: val_accuracy did not improve from 0.58481
# 9/9 [==============================] - 0s 44ms/step - loss: 1.0485 - accuracy: 0.4856 - mae: 0.4314 - mse: 0.2112 - val_loss: 1.0404 - val_accuracy: 0.5843 - val_mae: 0.4303 - val_mse: 0.2093 - lr: 0.0010
# Epoch 97/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0503 - accuracy: 0.4775 - mae: 0.4319 - mse: 0.2116
# Epoch 97: val_accuracy did not improve from 0.58481
# 9/9 [==============================] - 0s 43ms/step - loss: 1.0503 - accuracy: 0.4775 - mae: 0.4319 - mse: 0.2116 - val_loss: 1.0398 - val_accuracy: 0.5834 - val_mae: 0.4301 - val_mse: 0.2092 - lr: 0.0010
# Epoch 98/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0471 - accuracy: 0.4872 - mae: 0.4311 - mse: 0.2109
# Epoch 98: val_accuracy did not improve from 0.58481
# 9/9 [==============================] - 0s 43ms/step - loss: 1.0469 - accuracy: 0.4905 - mae: 0.4310 - mse: 0.2109 - val_loss: 1.0391 - val_accuracy: 0.5843 - val_mae: 0.4300 - val_mse: 0.2090 - lr: 0.0010
# Epoch 99/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0474 - accuracy: 0.4866 - mae: 0.4312 - mse: 0.2110
# Epoch 99: val_accuracy did not improve from 0.58481
# 9/9 [==============================] - 0s 42ms/step - loss: 1.0474 - accuracy: 0.4858 - mae: 0.4312 - mse: 0.2110 - val_loss: 1.0385 - val_accuracy: 0.5843 - val_mae: 0.4298 - val_mse: 0.2089 - lr: 0.0010
# Epoch 100/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0451 - accuracy: 0.4981 - mae: 0.4306 - mse: 0.2104
# Epoch 100: val_accuracy improved from 0.58481 to 0.58914, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0451 - accuracy: 0.4981 - mae: 0.4306 - mse: 0.2104 - val_loss: 1.0378 - val_accuracy: 0.5891 - val_mae: 0.4296 - val_mse: 0.2087 - lr: 0.0010
# Epoch 101/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0457 - accuracy: 0.4951 - mae: 0.4308 - mse: 0.2106
# Epoch 101: val_accuracy improved from 0.58914 to 0.59154, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 1.0457 - accuracy: 0.4951 - mae: 0.4308 - mse: 0.2106 - val_loss: 1.0372 - val_accuracy: 0.5915 - val_mae: 0.4295 - val_mse: 0.2086 - lr: 0.0010
# Epoch 102/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0452 - accuracy: 0.5004 - mae: 0.4306 - mse: 0.2105
# Epoch 102: val_accuracy improved from 0.59154 to 0.59250, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0444 - accuracy: 0.5035 - mae: 0.4304 - mse: 0.2103 - val_loss: 1.0365 - val_accuracy: 0.5925 - val_mae: 0.4293 - val_mse: 0.2085 - lr: 0.0010
# Epoch 103/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0437 - accuracy: 0.4947 - mae: 0.4303 - mse: 0.2102
# Epoch 103: val_accuracy improved from 0.59250 to 0.59298, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 58ms/step - loss: 1.0437 - accuracy: 0.4947 - mae: 0.4303 - mse: 0.2102 - val_loss: 1.0359 - val_accuracy: 0.5930 - val_mae: 0.4291 - val_mse: 0.2083 - lr: 0.0010
# Epoch 104/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0431 - accuracy: 0.5049 - mae: 0.4301 - mse: 0.2100
# Epoch 104: val_accuracy did not improve from 0.59298
# 9/9 [==============================] - 0s 44ms/step - loss: 1.0431 - accuracy: 0.5049 - mae: 0.4301 - mse: 0.2100 - val_loss: 1.0352 - val_accuracy: 0.5920 - val_mae: 0.4290 - val_mse: 0.2082 - lr: 0.0010
# Epoch 105/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0409 - accuracy: 0.5022 - mae: 0.4295 - mse: 0.2095
# Epoch 105: val_accuracy improved from 0.59298 to 0.59346, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0410 - accuracy: 0.5016 - mae: 0.4296 - mse: 0.2096 - val_loss: 1.0345 - val_accuracy: 0.5935 - val_mae: 0.4288 - val_mse: 0.2080 - lr: 0.0010
# Epoch 106/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0415 - accuracy: 0.5038 - mae: 0.4297 - mse: 0.2096
# Epoch 106: val_accuracy improved from 0.59346 to 0.59635, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0415 - accuracy: 0.5038 - mae: 0.4297 - mse: 0.2096 - val_loss: 1.0339 - val_accuracy: 0.5963 - val_mae: 0.4286 - val_mse: 0.2079 - lr: 0.0010
# Epoch 107/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0410 - accuracy: 0.5041 - mae: 0.4295 - mse: 0.2095
# Epoch 107: val_accuracy improved from 0.59635 to 0.59731, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 53ms/step - loss: 1.0410 - accuracy: 0.5041 - mae: 0.4295 - mse: 0.2095 - val_loss: 1.0332 - val_accuracy: 0.5973 - val_mae: 0.4285 - val_mse: 0.2077 - lr: 0.0010
# Epoch 108/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0397 - accuracy: 0.5153 - mae: 0.4292 - mse: 0.2092
# Epoch 108: val_accuracy improved from 0.59731 to 0.59827, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 1.0401 - accuracy: 0.5133 - mae: 0.4293 - mse: 0.2093 - val_loss: 1.0325 - val_accuracy: 0.5983 - val_mae: 0.4283 - val_mse: 0.2076 - lr: 0.0010
# Epoch 109/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0380 - accuracy: 0.5180 - mae: 0.4288 - mse: 0.2089
# Epoch 109: val_accuracy did not improve from 0.59827
# 9/9 [==============================] - 0s 41ms/step - loss: 1.0385 - accuracy: 0.5155 - mae: 0.4289 - mse: 0.2090 - val_loss: 1.0319 - val_accuracy: 0.5978 - val_mae: 0.4281 - val_mse: 0.2074 - lr: 0.0010
# Epoch 110/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0390 - accuracy: 0.5123 - mae: 0.4291 - mse: 0.2091
# Epoch 110: val_accuracy did not improve from 0.59827
# 9/9 [==============================] - 0s 41ms/step - loss: 1.0393 - accuracy: 0.5114 - mae: 0.4291 - mse: 0.2092 - val_loss: 1.0312 - val_accuracy: 0.5963 - val_mae: 0.4280 - val_mse: 0.2073 - lr: 0.0010
# Epoch 111/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0402 - accuracy: 0.5008 - mae: 0.4293 - mse: 0.2094
# Epoch 111: val_accuracy did not improve from 0.59827
# 9/9 [==============================] - 0s 45ms/step - loss: 1.0399 - accuracy: 0.5017 - mae: 0.4292 - mse: 0.2093 - val_loss: 1.0306 - val_accuracy: 0.5973 - val_mae: 0.4278 - val_mse: 0.2071 - lr: 0.0010
# Epoch 112/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 1.0398 - accuracy: 0.5086 - mae: 0.4292 - mse: 0.2093
# Epoch 112: val_accuracy did not improve from 0.59827
# 9/9 [==============================] - 0s 43ms/step - loss: 1.0395 - accuracy: 0.5100 - mae: 0.4291 - mse: 0.2092 - val_loss: 1.0299 - val_accuracy: 0.5978 - val_mae: 0.4276 - val_mse: 0.2070 - lr: 0.0010
# Epoch 113/1000
# 9/9 [==============================] - ETA: 0s - loss: 1.0399 - accuracy: 0.5030 - mae: 0.4292 - mse: 0.2093
# Epoch 113: val_accuracy did not improve from 0.59827
# 9/9 [==============================] - 0s 44ms/step - loss: 1.0399 - accuracy: 0.5030 - mae: 0.4292 - mse: 0.2093 - val_loss: 1.0292 - val_accuracy: 0.5978 - val_mae: 0.4274 - val_mse: 0.2068 - lr: 0.0010
# Epoch 114/1000
# ...
# Epoch 960/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6269 - accuracy: 0.7238 - mae: 0.2783 - mse: 0.1295
# Epoch 960: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 44ms/step - loss: 0.6242 - accuracy: 0.7254 - mae: 0.2775 - mse: 0.1288 - val_loss: 0.5929 - val_accuracy: 0.7247 - val_mae: 0.2696 - val_mse: 0.1217 - lr: 0.0010
# Epoch 961/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.7238 - mae: 0.2770 - mse: 0.1290
# Epoch 961: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6248 - accuracy: 0.7238 - mae: 0.2770 - mse: 0.1290 - val_loss: 0.5927 - val_accuracy: 0.7242 - val_mae: 0.2695 - val_mse: 0.1216 - lr: 0.0010
# Epoch 962/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6251 - accuracy: 0.7178 - mae: 0.2786 - mse: 0.1295
# Epoch 962: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 43ms/step - loss: 0.6233 - accuracy: 0.7204 - mae: 0.2780 - mse: 0.1289 - val_loss: 0.5925 - val_accuracy: 0.7242 - val_mae: 0.2694 - val_mse: 0.1216 - lr: 0.0010
# Epoch 963/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6251 - accuracy: 0.7181 - mae: 0.2777 - mse: 0.1293
# Epoch 963: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 47ms/step - loss: 0.6251 - accuracy: 0.7181 - mae: 0.2777 - mse: 0.1293 - val_loss: 0.5923 - val_accuracy: 0.7242 - val_mae: 0.2693 - val_mse: 0.1216 - lr: 0.0010
# Epoch 964/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6262 - accuracy: 0.7175 - mae: 0.2788 - mse: 0.1295
# Epoch 964: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6253 - accuracy: 0.7173 - mae: 0.2785 - mse: 0.1292 - val_loss: 0.5921 - val_accuracy: 0.7242 - val_mae: 0.2692 - val_mse: 0.1215 - lr: 0.0010
# Epoch 965/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6241 - accuracy: 0.7210 - mae: 0.2770 - mse: 0.1290
# Epoch 965: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 43ms/step - loss: 0.6241 - accuracy: 0.7210 - mae: 0.2770 - mse: 0.1290 - val_loss: 0.5920 - val_accuracy: 0.7242 - val_mae: 0.2692 - val_mse: 0.1215 - lr: 0.0010
# Epoch 966/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6259 - accuracy: 0.7217 - mae: 0.2779 - mse: 0.1294
# Epoch 966: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 46ms/step - loss: 0.6268 - accuracy: 0.7218 - mae: 0.2781 - mse: 0.1295 - val_loss: 0.5918 - val_accuracy: 0.7242 - val_mae: 0.2691 - val_mse: 0.1215 - lr: 0.0010
# Epoch 967/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.7190 - mae: 0.2772 - mse: 0.1290
# Epoch 967: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 43ms/step - loss: 0.6236 - accuracy: 0.7190 - mae: 0.2772 - mse: 0.1290 - val_loss: 0.5916 - val_accuracy: 0.7242 - val_mae: 0.2690 - val_mse: 0.1214 - lr: 0.0010
# Epoch 968/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6312 - accuracy: 0.7190 - mae: 0.2789 - mse: 0.1304
# Epoch 968: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 47ms/step - loss: 0.6306 - accuracy: 0.7197 - mae: 0.2787 - mse: 0.1303 - val_loss: 0.5914 - val_accuracy: 0.7247 - val_mae: 0.2689 - val_mse: 0.1214 - lr: 0.0010
# Epoch 969/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6267 - accuracy: 0.7175 - mae: 0.2781 - mse: 0.1298
# Epoch 969: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 47ms/step - loss: 0.6272 - accuracy: 0.7168 - mae: 0.2783 - mse: 0.1299 - val_loss: 0.5913 - val_accuracy: 0.7247 - val_mae: 0.2688 - val_mse: 0.1214 - lr: 0.0010
# Epoch 970/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6200 - accuracy: 0.7245 - mae: 0.2767 - mse: 0.1280
# Epoch 970: val_accuracy did not improve from 0.72465
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6240 - accuracy: 0.7206 - mae: 0.2782 - mse: 0.1292 - val_loss: 0.5911 - val_accuracy: 0.7247 - val_mae: 0.2687 - val_mse: 0.1213 - lr: 0.0010
# Epoch 971/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6220 - accuracy: 0.7208 - mae: 0.2759 - mse: 0.1285
# Epoch 971: val_accuracy improved from 0.72465 to 0.72513, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6220 - accuracy: 0.7208 - mae: 0.2759 - mse: 0.1285 - val_loss: 0.5909 - val_accuracy: 0.7251 - val_mae: 0.2686 - val_mse: 0.1213 - lr: 0.0010
# Epoch 972/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6204 - accuracy: 0.7267 - mae: 0.2766 - mse: 0.1280
# Epoch 972: val_accuracy did not improve from 0.72513
# 9/9 [==============================] - 0s 44ms/step - loss: 0.6204 - accuracy: 0.7267 - mae: 0.2766 - mse: 0.1280 - val_loss: 0.5907 - val_accuracy: 0.7251 - val_mae: 0.2686 - val_mse: 0.1213 - lr: 0.0010
# Epoch 973/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.7249 - mae: 0.2766 - mse: 0.1286
# Epoch 973: val_accuracy did not improve from 0.72513
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6223 - accuracy: 0.7249 - mae: 0.2766 - mse: 0.1286 - val_loss: 0.5905 - val_accuracy: 0.7251 - val_mae: 0.2685 - val_mse: 0.1212 - lr: 0.0010
# Epoch 974/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6181 - accuracy: 0.7215 - mae: 0.2757 - mse: 0.1275
# Epoch 974: val_accuracy did not improve from 0.72513
# 9/9 [==============================] - 0s 42ms/step - loss: 0.6223 - accuracy: 0.7183 - mae: 0.2770 - mse: 0.1286 - val_loss: 0.5903 - val_accuracy: 0.7251 - val_mae: 0.2684 - val_mse: 0.1212 - lr: 0.0010
# Epoch 975/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6189 - accuracy: 0.7203 - mae: 0.2758 - mse: 0.1276
# Epoch 975: val_accuracy did not improve from 0.72513
# 9/9 [==============================] - 0s 46ms/step - loss: 0.6202 - accuracy: 0.7197 - mae: 0.2758 - mse: 0.1280 - val_loss: 0.5902 - val_accuracy: 0.7251 - val_mae: 0.2684 - val_mse: 0.1212 - lr: 0.0010
# Epoch 976/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6257 - accuracy: 0.7181 - mae: 0.2774 - mse: 0.1295
# Epoch 976: val_accuracy did not improve from 0.72513
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6279 - accuracy: 0.7173 - mae: 0.2778 - mse: 0.1300 - val_loss: 0.5900 - val_accuracy: 0.7251 - val_mae: 0.2683 - val_mse: 0.1211 - lr: 0.0010
# Epoch 977/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.7196 - mae: 0.2766 - mse: 0.1285
# Epoch 977: val_accuracy did not improve from 0.72513
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6218 - accuracy: 0.7196 - mae: 0.2766 - mse: 0.1285 - val_loss: 0.5898 - val_accuracy: 0.7251 - val_mae: 0.2681 - val_mse: 0.1211 - lr: 0.0010
# Epoch 978/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6239 - accuracy: 0.7240 - mae: 0.2773 - mse: 0.1290
# Epoch 978: val_accuracy improved from 0.72513 to 0.72561, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 54ms/step - loss: 0.6237 - accuracy: 0.7240 - mae: 0.2773 - mse: 0.1289 - val_loss: 0.5896 - val_accuracy: 0.7256 - val_mae: 0.2680 - val_mse: 0.1211 - lr: 0.0010
# Epoch 979/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6220 - accuracy: 0.7207 - mae: 0.2761 - mse: 0.1286
# Epoch 979: val_accuracy did not improve from 0.72561
# 9/9 [==============================] - 0s 42ms/step - loss: 0.6185 - accuracy: 0.7218 - mae: 0.2751 - mse: 0.1278 - val_loss: 0.5895 - val_accuracy: 0.7251 - val_mae: 0.2679 - val_mse: 0.1210 - lr: 0.0010
# Epoch 980/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6246 - accuracy: 0.7185 - mae: 0.2779 - mse: 0.1293
# Epoch 980: val_accuracy did not improve from 0.72561
# 9/9 [==============================] - 0s 46ms/step - loss: 0.6240 - accuracy: 0.7190 - mae: 0.2777 - mse: 0.1292 - val_loss: 0.5893 - val_accuracy: 0.7251 - val_mae: 0.2679 - val_mse: 0.1210 - lr: 0.0010
# Epoch 981/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6269 - accuracy: 0.7185 - mae: 0.2777 - mse: 0.1296
# Epoch 981: val_accuracy did not improve from 0.72561
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6260 - accuracy: 0.7195 - mae: 0.2774 - mse: 0.1293 - val_loss: 0.5891 - val_accuracy: 0.7251 - val_mae: 0.2678 - val_mse: 0.1210 - lr: 0.0010
# Epoch 982/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6169 - accuracy: 0.7218 - mae: 0.2753 - mse: 0.1276
# Epoch 982: val_accuracy improved from 0.72561 to 0.72609, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6186 - accuracy: 0.7207 - mae: 0.2755 - mse: 0.1280 - val_loss: 0.5889 - val_accuracy: 0.7261 - val_mae: 0.2677 - val_mse: 0.1209 - lr: 0.0010
# Epoch 983/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6272 - accuracy: 0.7171 - mae: 0.2775 - mse: 0.1301
# Epoch 983: val_accuracy did not improve from 0.72609
# 9/9 [==============================] - 0s 46ms/step - loss: 0.6245 - accuracy: 0.7194 - mae: 0.2767 - mse: 0.1293 - val_loss: 0.5887 - val_accuracy: 0.7256 - val_mae: 0.2676 - val_mse: 0.1209 - lr: 0.0010
# Epoch 984/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6210 - accuracy: 0.7196 - mae: 0.2760 - mse: 0.1287
# Epoch 984: val_accuracy did not improve from 0.72609
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6195 - accuracy: 0.7224 - mae: 0.2756 - mse: 0.1283 - val_loss: 0.5885 - val_accuracy: 0.7261 - val_mae: 0.2676 - val_mse: 0.1209 - lr: 0.0010
# Epoch 985/1000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6214 - accuracy: 0.7242 - mae: 0.2757 - mse: 0.1284
# Epoch 985: val_accuracy did not improve from 0.72609
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6210 - accuracy: 0.7243 - mae: 0.2756 - mse: 0.1283 - val_loss: 0.5884 - val_accuracy: 0.7261 - val_mae: 0.2675 - val_mse: 0.1208 - lr: 0.0010
# Epoch 986/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6202 - accuracy: 0.7203 - mae: 0.2760 - mse: 0.1283
# Epoch 986: val_accuracy did not improve from 0.72609
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6202 - accuracy: 0.7203 - mae: 0.2760 - mse: 0.1283 - val_loss: 0.5882 - val_accuracy: 0.7261 - val_mae: 0.2674 - val_mse: 0.1208 - lr: 0.0010
# Epoch 987/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6217 - accuracy: 0.7238 - mae: 0.2763 - mse: 0.1287
# Epoch 987: val_accuracy did not improve from 0.72609
# 9/9 [==============================] - 0s 47ms/step - loss: 0.6217 - accuracy: 0.7238 - mae: 0.2763 - mse: 0.1287 - val_loss: 0.5880 - val_accuracy: 0.7261 - val_mae: 0.2673 - val_mse: 0.1208 - lr: 0.0010
# Epoch 988/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6191 - accuracy: 0.7234 - mae: 0.2759 - mse: 0.1280
# Epoch 988: val_accuracy improved from 0.72609 to 0.72705, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6191 - accuracy: 0.7234 - mae: 0.2759 - mse: 0.1280 - val_loss: 0.5878 - val_accuracy: 0.7271 - val_mae: 0.2672 - val_mse: 0.1207 - lr: 0.0010
# Epoch 989/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6177 - accuracy: 0.7153 - mae: 0.2741 - mse: 0.1276
# Epoch 989: val_accuracy did not improve from 0.72705
# 9/9 [==============================] - 0s 42ms/step - loss: 0.6182 - accuracy: 0.7166 - mae: 0.2747 - mse: 0.1278 - val_loss: 0.5877 - val_accuracy: 0.7271 - val_mae: 0.2671 - val_mse: 0.1207 - lr: 0.0010
# Epoch 990/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6191 - accuracy: 0.7235 - mae: 0.2751 - mse: 0.1279
# Epoch 990: val_accuracy improved from 0.72705 to 0.72753, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 0.6183 - accuracy: 0.7236 - mae: 0.2750 - mse: 0.1277 - val_loss: 0.5875 - val_accuracy: 0.7275 - val_mae: 0.2671 - val_mse: 0.1207 - lr: 0.0010
# Epoch 991/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6241 - accuracy: 0.7197 - mae: 0.2765 - mse: 0.1293
# Epoch 991: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 44ms/step - loss: 0.6210 - accuracy: 0.7231 - mae: 0.2755 - mse: 0.1285 - val_loss: 0.5873 - val_accuracy: 0.7275 - val_mae: 0.2670 - val_mse: 0.1206 - lr: 0.0010
# Epoch 992/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6231 - accuracy: 0.7211 - mae: 0.2762 - mse: 0.1287
# Epoch 992: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 44ms/step - loss: 0.6198 - accuracy: 0.7225 - mae: 0.2752 - mse: 0.1280 - val_loss: 0.5871 - val_accuracy: 0.7275 - val_mae: 0.2669 - val_mse: 0.1206 - lr: 0.0010
# Epoch 993/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6238 - accuracy: 0.7180 - mae: 0.2764 - mse: 0.1291
# Epoch 993: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6238 - accuracy: 0.7180 - mae: 0.2764 - mse: 0.1291 - val_loss: 0.5869 - val_accuracy: 0.7275 - val_mae: 0.2669 - val_mse: 0.1206 - lr: 0.0010
# Epoch 994/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6156 - accuracy: 0.7280 - mae: 0.2742 - mse: 0.1270
# Epoch 994: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6192 - accuracy: 0.7250 - mae: 0.2752 - mse: 0.1279 - val_loss: 0.5868 - val_accuracy: 0.7275 - val_mae: 0.2668 - val_mse: 0.1205 - lr: 0.0010
# Epoch 995/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6167 - accuracy: 0.7174 - mae: 0.2744 - mse: 0.1276
# Epoch 995: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 44ms/step - loss: 0.6167 - accuracy: 0.7174 - mae: 0.2744 - mse: 0.1276 - val_loss: 0.5866 - val_accuracy: 0.7275 - val_mae: 0.2667 - val_mse: 0.1205 - lr: 0.0010
# Epoch 996/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6097 - accuracy: 0.7278 - mae: 0.2726 - mse: 0.1258
# Epoch 996: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6126 - accuracy: 0.7260 - mae: 0.2731 - mse: 0.1265 - val_loss: 0.5864 - val_accuracy: 0.7275 - val_mae: 0.2666 - val_mse: 0.1205 - lr: 0.0010
# Epoch 997/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6217 - accuracy: 0.7142 - mae: 0.2754 - mse: 0.1287
# Epoch 997: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 44ms/step - loss: 0.6217 - accuracy: 0.7142 - mae: 0.2754 - mse: 0.1287 - val_loss: 0.5862 - val_accuracy: 0.7275 - val_mae: 0.2666 - val_mse: 0.1204 - lr: 0.0010
# Epoch 998/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6171 - accuracy: 0.7222 - mae: 0.2745 - mse: 0.1275
# Epoch 998: val_accuracy did not improve from 0.72753
# 9/9 [==============================] - 0s 45ms/step - loss: 0.6171 - accuracy: 0.7222 - mae: 0.2745 - mse: 0.1275 - val_loss: 0.5861 - val_accuracy: 0.7275 - val_mae: 0.2665 - val_mse: 0.1204 - lr: 0.0010
# Epoch 999/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.6180 - accuracy: 0.7209 - mae: 0.2745 - mse: 0.1277
# Epoch 999: val_accuracy improved from 0.72753 to 0.72802, saving model to data/4_best_model_keras.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 0.6180 - accuracy: 0.7209 - mae: 0.2745 - mse: 0.1277 - val_loss: 0.5859 - val_accuracy: 0.7280 - val_mae: 0.2664 - val_mse: 0.1204 - lr: 0.0010
# Epoch 1000/1000
# 7/9 [======================>.......] - ETA: 0s - loss: 0.6216 - accuracy: 0.7222 - mae: 0.2757 - mse: 0.1288
# Epoch 1000: val_accuracy did not improve from 0.72802
# 9/9 [==============================] - 0s 41ms/step - loss: 0.6205 - accuracy: 0.7239 - mae: 0.2754 - mse: 0.1286 - val_loss: 0.5857 - val_accuracy: 0.7280 - val_mae: 0.2664 - val_mse: 0.1203 - lr: 0.0010

# %% [markdown]
# ###Model Evaluation

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.figure()

plt.plot(hist.history['val_loss'])
plt.plot(hist.history['accuracy'])

plt.title(f'Model Loss and Accuracy')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'accuracy'], loc='upper left')

plt.show()

print("Model Accuracy:", hist.history['accuracy'][999])
print("Model Validation Loss:", hist.history['val_loss'][999])
# Out:
# Model Accuracy: 0.7239182591438293
# Model Validation Loss: 0.5857243537902832

# %% [markdown]
# ###Test CNN

# %%
from sklearn.metrics import classification_report, confusion_matrix

# use model to make predictions on test data
y_predict = model.predict(X_test_images)
y_predict = np.argmax(y_predict, axis=1)
y_true = np.argmax(y_test, axis=0)

rounded_labels = np.argmax(y_test, axis=1) # convert label to single-digit

cm = confusion_matrix(rounded_labels, y_predict)
print(cm)
print(classification_report(rounded_labels, y_predict))
# Out:
# 82/82 [==============================] - 0s 3ms/step
# [[387 245 235]
#  [105 762   0]
#  [ 95   0 772]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.45      0.53       867
#            1       0.76      0.88      0.81       867
#            2       0.77      0.89      0.82       867
#
#     accuracy                           0.74      2601
#    macro avg       0.73      0.74      0.72      2601
# weighted avg       0.73      0.74      0.72      2601
